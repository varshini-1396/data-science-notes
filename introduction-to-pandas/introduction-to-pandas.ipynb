# %%
import pandas as pd

# %%
#2 main data types

# %%
series=pd.Series(["BMW","Toyota","honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     honda
# dtype: object

# %%
#series=1-Dimensional

# %%
colour=pd.Series(["red","blue","green"])

# %%
colour
# Out:
# 0      red
# 1     blue
# 2    green
# dtype: object

# %%
#data frame= 2-Dimensional

# %%
car_data=pd.DataFrame({"car": series,"colour": colour})

# %%
car_data
# Out:
#       car colour
# 0     BMW    red
# 1  Toyota   blue
# 2   honda  green

# %%
#import 
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![anatomy](pandas-anatomy-of-a-dataframe.png)

# %%
# Export a DataFrame
car_sales.to_csv("Exported_car_sales.csv",index=False)

# %%
# Re-importing exported files (to check)
exported_car_sales=pd.read_csv("Exported_car_sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# **Describe Data**

# %%
#Attributes
car_sales.dtypes
#Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#Gives column names
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns

# %%
#Gives index range
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#describes the data... analyses
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#Gives entire info about the data frame
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
#Give mean of the columns having the numercal values
car_sales.mean(numeric_only = True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
#Gives mean of the particular column having numerical Values
car_sales["Doors"].mean(numeric_only = True)
# Out:
# 4.0

# %%
#Gives sum of the particular column having numerical values
car_sales["Doors"].sum(numeric_only = True)
# Out:
# 40

# %%
#it will give number of rows int the car_sales dataframe
len(car_sales)
# Out:
# 10

# %% [markdown]
# **Viewing and Selecting Data**

# %%
car_sales.head(7) #By default 5
#will give first 5 rows of the file
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(3) #By deafult 5
#it will give last 5 rows of the file
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc and iloc
animals=pd.Series(["cat","dog","panda","tiger","lion"],index=[4,5,4,6,2])

# %%
animals.loc[4]
# Out:
# 4      cat
# 4    panda
# dtype: object

# %%
animals
# Out:
# 4      cat
# 5      dog
# 4    panda
# 6    tiger
# 2     lion
# dtype: object

# %%
#iloc refers to position whereas loc refers to index
animals.iloc[4]
# Out:
# 'lion'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#includes 3rd row
# same as car_sales.head(4)
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#excludes 3rd row
animals.iloc[:3]
# Out:
# 4      cat
# 5      dog
# 4    panda
# dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
#same as car_sales["Colour"] 
car_sales.Colour
#car_sales.Colour won't work if our column name has spaces
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
# gives the rows which satisfy the condition
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
#Two compare two columns
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# It groups the data frame on the Make Column
car_sales.groupby(car_sales["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
#To group by using a column using a specific type
car_sales[car_sales["Make"]=="Toyota"].groupby("Make").mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# Toyota       85451.25   3.75

# %%
#To group by using two column using a specific type
car_sales[ (car_sales["Make"] == "Toyota") & (car_sales["Colour"] == "White")].groupby(["Make", "Colour"]).mean(numeric_only=True)
# Out:
#                Odometer (KM)  Doors
# Make   Colour
# Toyota White        105021.5    4.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Plotting
car_sales["Odometer (KM)"].plot()
plt.xlabel("Odometer (KM)")
plt.show()

# %%
#Plotting the Histogram
car_sales["Odometer (KM)"].hist()
plt.xlabel("Odometer (KM)")
plt.show()

# %%
#To convert Price colum from object to int by replacing $,.
car_sales["Price"] = car_sales["Price"].replace(r'[\$,\.]', '', regex=True).astype(int)
#But it's also removing the decimal point

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# **Manipulating Data**

# %%
#string method to convert to lower case but doesn't actually change the original data
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# NaN -> to show missing data in the data frame
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True))
#This will return the column of odometer where the missinng values are filled with mean of that column
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
#But it didn't actually change the data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#Assignment with change the data and fill the missing values
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#removes the rows which has misisng data
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
#.dropna() doesn't change the data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#inplace=True -> data will be modified
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#to re import the missing data
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
#Exporting
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
#Column from series
seats_column=pd.Series([5,5,5,5,5,5])

#Adding a new column called seats
car_sales["Seats"]=seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"]=car_sales["Seats"].fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
#Column with python list
#fuel = [8.2,8.9,5.3,8.8,7.5]
# car_sales["Fuel per 100KM"]= fuel  -> it  will throw an error.
#Because when creating a column from python list, it should exactly have same number of items as the length of the Data Frame
fuel = [8.2,8.9,5.3,8.8,7.5,9.2,9.1,7.6,9.5,4.9]
car_sales["Fuel per 100KM"]= fuel

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM
# 0  toyota  White         150043      4   400000    5.0             8.2
# 1   honda    Red          87899      4   500000    5.0             8.9
# 2  toyota   Blue          32549      3   700000    5.0             5.3
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             7.5
# 5  toyota  Green          99213      4   450000    5.0             9.2
# 6   honda   Blue          45698      4   750000    5.0             9.1
# 7   honda   Blue          54738      4   700000    5.0             7.6
# 8  toyota  White          60000      4   625000    5.0             9.5
# 9  nissan  White          31600      4   970000    5.0             4.9

# %%
#Creating a column using two columns
car_sales["Total Fuel Used (in L)"] = (car_sales["Odometer (KM)"]/100) * car_sales["Fuel per 100KM"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             8.2
# 1   honda    Red          87899      4   500000    5.0             8.9
# 2  toyota   Blue          32549      3   700000    5.0             5.3
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             7.5
# 5  toyota  Green          99213      4   450000    5.0             9.2
# 6   honda   Blue          45698      4   750000    5.0             9.1
# 7   honda   Blue          54738      4   700000    5.0             7.6
# 8  toyota  White          60000      4   625000    5.0             9.5
# 9  nissan  White          31600      4   970000    5.0             4.9
#
#    Total Fuel Used (in L)
# 0               12303.526
# 1                7823.011
# 2                1725.097
# 3                 983.752
# 4               15982.125
# ...

# %%
#Creating a column using one value
car_sales["No of Wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             8.2
# 1   honda    Red          87899      4   500000    5.0             8.9
# 2  toyota   Blue          32549      3   700000    5.0             5.3
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             7.5
# 5  toyota  Green          99213      4   450000    5.0             9.2
# 6   honda   Blue          45698      4   750000    5.0             9.1
# 7   honda   Blue          54738      4   700000    5.0             7.6
# 8  toyota  White          60000      4   625000    5.0             9.5
# 9  nissan  White          31600      4   970000    5.0             4.9
#
#    Total Fuel Used (in L)  No of Wheels
# 0               12303.526             4
# 1                7823.011             4
# 2                1725.097             4
# ...

# %%
car_sales["Passed Road Safety"]=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000    5.0             8.2
# 1   honda    Red          87899      4   500000    5.0             8.9
# 2  toyota   Blue          32549      3   700000    5.0             5.3
# 3     bmw  Black          11179      5  2200000    5.0             8.8
# 4  nissan  White         213095      4   350000    5.0             7.5
# 5  toyota  Green          99213      4   450000    5.0             9.2
# 6   honda   Blue          45698      4   750000    5.0             9.1
# 7   honda   Blue          54738      4   700000    5.0             7.6
# 8  toyota  White          60000      4   625000    5.0             9.5
# 9  nissan  White          31600      4   970000    5.0             4.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 0               12303.526             4                True
# 1                7823.011             4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                       object
# Colour                     object
# Odometer (KM)               int64
# Doors                       int64
# Price                       int32
# Seats                     float64
# Fuel per 100KM            float64
# Total Fuel Used (in L)    float64
# No of Wheels                int64
# Passed Road Safety           bool
# dtype: object

# %%
#drop function to remove the column, axis=1 indicates a column
car_sales=car_sales.drop("Seats",axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             8.2
# 1   honda    Red          87899      4   500000             8.9
# 2  toyota   Blue          32549      3   700000             5.3
# 3     bmw  Black          11179      5  2200000             8.8
# 4  nissan  White         213095      4   350000             7.5
# 5  toyota  Green          99213      4   450000             9.2
# 6   honda   Blue          45698      4   750000             9.1
# 7   honda   Blue          54738      4   700000             7.6
# 8  toyota  White          60000      4   625000             9.5
# 9  nissan  White          31600      4   970000             4.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 0               12303.526             4                True
# 1                7823.011             4                True
# 2                1725.097             4                True
# ...

# %%
#randomly gives 0.5 fraction of the data
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 1   honda    Red          87899      4   500000             8.9
# 5  toyota  Green          99213      4   450000             9.2
# 8  toyota  White          60000      4   625000             9.5
# 2  toyota   Blue          32549      3   700000             5.3
# 3     bmw  Black          11179      5  2200000             8.8
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 1                7823.011             4                True
# 5                9127.596             4                True
# 8                5700.000             4                True
# 2                1725.097             4                True
# 3                 983.752             4                True

# %%
#shuffles the data
#information in rows will not chnage
car_sales.sample(frac=1)
#but doesn't change the original data Frame
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 9  nissan  White          31600      4   970000             4.9
# 4  nissan  White         213095      4   350000             7.5
# 2  toyota   Blue          32549      3   700000             5.3
# 0  toyota  White         150043      4   400000             8.2
# 3     bmw  Black          11179      5  2200000             8.8
# 8  toyota  White          60000      4   625000             9.5
# 1   honda    Red          87899      4   500000             8.9
# 6   honda   Blue          45698      4   750000             9.1
# 7   honda   Blue          54738      4   700000             7.6
# 5  toyota  Green          99213      4   450000             9.2
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 9                1548.400             4                True
# 4               15982.125             4                True
# 2                1725.097             4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 8  toyota  White          60000      4   625000             9.5
# 6   honda   Blue          45698      4   750000             9.1
# 3     bmw  Black          11179      5  2200000             8.8
# 7   honda   Blue          54738      4   700000             7.6
# 9  nissan  White          31600      4   970000             4.9
# 4  nissan  White         213095      4   350000             7.5
# 0  toyota  White         150043      4   400000             8.2
# 2  toyota   Blue          32549      3   700000             5.3
# 5  toyota  Green          99213      4   450000             9.2
# 1   honda    Red          87899      4   500000             8.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 8                5700.000             4                True
# 6                4158.518             4                True
# 3                 983.752             4                True
# ...

# %%
#only select 20% data or it depends on the amount of data we're working on
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Fuel per 100KM  \
# 7   honda   Blue          54738      4  700000             7.6
# 9  nissan  White          31600      4  970000             4.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 7                4160.088             4                True
# 9                1548.400             4                True

# %%
#will change the dataframe in order with the index
#drop=True  -> so that new column of old index won't be created
#inplace=True  -> instead of assigning
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White          60000      4   625000             9.5
# 1   honda   Blue          45698      4   750000             9.1
# 2     bmw  Black          11179      5  2200000             8.8
# 3   honda   Blue          54738      4   700000             7.6
# 4  nissan  White          31600      4   970000             4.9
# 5  nissan  White         213095      4   350000             7.5
# 6  toyota  White         150043      4   400000             8.2
# 7  toyota   Blue          32549      3   700000             5.3
# 8  toyota  Green          99213      4   450000             9.2
# 9   honda    Red          87899      4   500000             8.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 0                5700.000             4                True
# 1                4158.518             4                True
# 2                 983.752             4                True
# ...

# %%
#lambda is a keyword in python in short for an anonymous function 
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000             8.2
# 1   honda    Red      54936.875      4   500000             8.9
# 2  toyota   Blue      20343.125      3   700000             5.3
# 3     bmw  Black       6986.875      5  2200000             8.8
# 4  nissan  White     133184.375      4   350000             7.5
# 5  toyota  Green      62008.125      4   450000             9.2
# 6   honda   Blue      28561.250      4   750000             9.1
# 7   honda   Blue      34211.250      4   700000             7.6
# 8  toyota  White      37500.000      4   625000             9.5
# 9  nissan  White      19750.000      4   970000             4.9
#
#    Total Fuel Used (in L)  No of Wheels  Passed Road Safety
# 0               12303.526             4                True
# 1                7823.011             4                True
# 2                1725.097             4                True
# ...
